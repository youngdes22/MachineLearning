# %%
# 建立網頁與串接 LINE Bot 相關的函式庫
# !pip install Flask pyngrok line-bot-sdk requests # openai
# !pip install google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 9.3 MB/s eta 0:00:00
# ...

# %%
#從 Colab 的環境變數中取得金鑰，並指定伺服器運作的通道
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
port=5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
#設定 ngrok 驗證金鑰
ngrok.set_auth_token(ngrok_authtoken)
# 建立一個名為 linebot_tunnel 的連線，並指向指定的 port
tunnel = ngrok.connect(port, name="linebot_tunnel")
# 印出對外公開的網址
print(tunnel.public_url)
# Out:
# https://senior-favorably-fasting.ngrok-free.dev

# %%
from flask import Flask

app = Flask(__name__)

# 定義首頁路由 ('/')
@app.route('/')
def home():
    return "<h1>明新科技大學楊博宇連線成功</h1>"

# 啟動伺服器
if __name__ == '__main__':
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [23/Apr/2026 22:37:35] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/Apr/2026 22:37:35] "GET /favicon.ico HTTP/1.1" 404 -

# %%
ngrok.kill()
